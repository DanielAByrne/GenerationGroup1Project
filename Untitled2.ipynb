# %%
import pandas as pd

# %%
df = pd.read_csv('chesterfield_25-08-2021_09-00-00 copy - chesterfield_25-08-2021_09-00-00 copy.csv', sep=',')

# %%
df.explode('ITEMS_ORDERED')

# %%
print(df)
# Out:
#     DATETIME           LOCATION       CUST_NAME               \
# 0   25/08/2021 09:00   Chesterfield   Richard Copeland
# 1
# 2   25/08/2021 09:02   Chesterfield   Scott Owens
# 3
# 4
# 5
# 6
# 7
# 8   25/08/2021 09:04   Chesterfield   Francis Strayhorn
# 9
# 10  25/08/2021 09:06   Chesterfield   Rodney Drake
# 11
# 12  25/08/2021 09:08   Chesterfield   Michael Sparrow
# 13
# 14  25/08/2021 09:10   Chesterfield   Thomas Register
# 15
# 16
# 17
# 18
# 19  25/08/2021 09:12   Chesterfield   James Petrick
# 20
# 21
# 22
# 23
# 24
# 25  25/08/2021 09:14   Chesterfield   Ronald Hagy
# 26
# 27
# 28
# 29
# 30  25/08/2021 09:17   Chesterfield   Lashawn Fant
# 31
# 32
# 33
# 34
# 35  25/08/2021 09:19   Chesterfield   James Folsom
# 36
# 37  25/08/2021 09:21   Chesterfield   Tina Burke
# 38
# 39
# 40
# 41
#
# ...
